# %%
# Reads data from the combined csv obtained from database 

# !python -m pip install dask[dataframe]
from google.colab import drive 
import dask.dataframe as dd

drive.mount('/content/gdrive')

df = dd.read_csv("gdrive/My Drive/combined_all.csv")
df.describe()
# Out:
# ...
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# Dask DataFrame Structure:
# ...

# %%
# Subsets columns to be included for analysis 

llist = ["tbirth_year","egender","rrace","eeduc","recvdvacc",
         "hadcovid","kindwork","anywork","delay",
         "notget","mh_notget","income","est_st","week","privhlth",
         "thhld_numper","thhld_numkid","expns_dif","anxious","down",
         "curfoodsuf"]
llist = [i.upper() for i in llist]

df = df[llist].compute()

# %%
# Saves the selected columns to a new csv file 

df.to_csv("data.csv")
